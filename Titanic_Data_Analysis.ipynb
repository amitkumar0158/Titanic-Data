# %% [markdown]
# <a href="https://colab.research.google.com/github/amitkumar0158/Titanic-Data/blob/master/Titanic_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("https://raw.githubusercontent.com/amitkumar0158/Titanic-Data/master/datasets_11657_16098_train.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass  ...   Fare Cabin  Embarked
# 886          887         0       2  ...  13.00   NaN         S
# 887          888         1       1  ...  30.00   B42         S
# 888          889         0       3  ...  23.45   NaN         S
# 889          890         1       1  ...  30.00  C148         C
# 890          891         0       3  ...   7.75   NaN         Q
#
# [5 rows x 12 columns]

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass  ...       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  ...  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642  ...    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071  ...    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000  ...    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000  ...    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000  ...    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000  ...    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000  ...    8.000000    6.000000  512.329200
#
# [8 rows x 7 columns]

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df = df.drop(["Cabin"], axis =1)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  ...            Ticket     Fare  Embarked
# 0              1         0       3  ...         A/5 21171   7.2500         S
# 1              2         1       1  ...          PC 17599  71.2833         C
# 2              3         1       3  ...  STON/O2. 3101282   7.9250         S
# 3              4         1       1  ...            113803  53.1000         S
# 4              5         0       3  ...            373450   8.0500         S
# ..           ...       ...     ...  ...               ...      ...       ...
# 886          887         0       2  ...            211536  13.0000         S
# 887          888         1       1  ...            112053  30.0000         S
# 888          889         0       3  ...        W./C. 6607  23.4500         S
# 889          890         1       1  ...            111369  30.0000         C
# 890          891         0       3  ...            370376   7.7500         Q
#
# [891 rows x 11 columns]

# %%
df['Age'] = df['Age'].fillna(df["Age"].mean())

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %%
df.Embarked.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object>

# %%
df["Embarked"] = df["Embarked"].fillna("S")

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder_sex = LabelEncoder()
df.iloc[:,[4]] = labelencoder_sex.fit_transform(df.iloc[:,[4]])
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:251: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  ...            Ticket     Fare  Embarked
# 0            1         0       3  ...         A/5 21171   7.2500         S
# 1            2         1       1  ...          PC 17599  71.2833         C
# 2            3         1       3  ...  STON/O2. 3101282   7.9250         S
# 3            4         1       1  ...            113803  53.1000         S
# 4            5         0       3  ...            373450   8.0500         S
#
# [5 rows x 11 columns]

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder_Embarked = LabelEncoder()
df.iloc[:,[10]] = labelencoder_Embarked.fit_transform(df.iloc[:,[10]])
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py:251: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
df = pd.get_dummies(df,columns =["Pclass","Embarked"])

# %%
df.head()
# Out:
#    PassengerId  Survived  ... Embarked_1  Embarked_2
# 0            1         0  ...          0           1
# 1            2         1  ...          0           0
# 2            3         1  ...          0           1
# 3            4         1  ...          0           1
# 4            5         0  ...          0           1
#
# [5 rows x 15 columns]

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Pclass_1', 'Pclass_2', 'Pclass_3', 'Embarked_0',
#        'Embarked_1', 'Embarked_2'],
#       dtype='object')

# %%
df["Family_Size"] = df["SibSp"] + df["Parch"]+1

# %%
df["Gender"] = df.Sex.apply(lambda x:1 if x==1 else 0)

# %%
df.head()
# Out:
#    PassengerId  Survived  ... Family_Size  Gender
# 0            1         0  ...           2       1
# 1            2         1  ...           2       0
# 2            3         1  ...           1       0
# 3            4         1  ...           2       0
# 4            5         0  ...           1       1
#
# [5 rows x 17 columns]

# %%
survived = df[df['Survived'] == 1]
not_survived = df[df['Survived'] == 0]
df.head()
# Out:
#    PassengerId  Survived  ... Family_Size  Gender
# 0            1         0  ...           2       1
# 1            2         1  ...           2       0
# 2            3         1  ...           1       0
# 3            4         1  ...           2       0
# 4            5         0  ...           1       1
#
# [5 rows x 17 columns]

# %%
p = sns.countplot(x ="Survived" , data = df)
p.set_xlabel("0 = Death, 1 = Alive ")
p.set_title("Survival Report of Passengers")
# Out:
# Text(0.5, 1.0, 'Survival Report of Passengers')

# %%
p = sns.countplot(x = "Sex", data = df)
p.set_xlabel("0 = male , 1 = female")
p.set_title("Survival Report Based on sex")
# Out:
# Text(0.5, 1.0, 'Survival Report Based on sex')

# %%
sns.boxplot(y = "Age", data = df)

# %%
sns.heatmap(df.corr())

# %%
sns.pairplot(df)
